# %% [markdown]
# 1. Tentukan library yang akan digunakan

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %% [markdown]
# 2. Load Data

# %%
Kerusakan_mesin = pd.read_csv('kerusakan_data.csv')

# %%
Kerusakan_mesin.head()
# Out:
#    footfall  tempMode  AQ  USS  CS  VOC  RP  IP  Temperature  fail
# 0         0         7   7    1   6    6  36   3            1     1
# 1       190         1   3    3   5    1  20   4            1     0
# 2        31         7   2    2   6    1  24   6            1     0
# 3        83         4   3    4   5    1  28   6            1     0
# 4       640         7   5    6   4    0  68   6            1     0

# %%
Kerusakan_mesin.shape
# Out:
# (944, 10)

# %%
Kerusakan_mesin['fail'].value_counts()
# Out:
# fail
# 0    551
# 1    393
# Name: count, dtype: int64

# %% [markdown]
# 3. pisahkan data atribut dan label

# %%
x = Kerusakan_mesin.drop(columns='fail', axis=1)
y = Kerusakan_mesin['fail']

# %%
print(x)
print(y)
# Out:
#      footfall  tempMode  AQ  USS  CS  VOC  RP  IP  Temperature
# 0           0         7   7    1   6    6  36   3            1
# 1         190         1   3    3   5    1  20   4            1
# 2          31         7   2    2   6    1  24   6            1
# 3          83         4   3    4   5    1  28   6            1
# 4         640         7   5    6   4    0  68   6            1
# ..        ...       ...  ..  ...  ..  ...  ..  ..          ...
# 939         0         7   7    1   6    4  73   6           24
# 940         0         7   5    2   6    6  50   6           24
# 941         0         3   6    2   7    5  43   6           24
# 942         0         6   6    2   5    6  46   7           24
# 943        18         7   4    2   6    3  61   7           24
#
# [944 rows x 9 columns]
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 939    1
# 940    1
# 941    1
# 942    1
# 943    1
# Name: fail, Length: 944, dtype: int64

# %% [markdown]
# 4. Split data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (944, 9) (566, 9) (378, 9)

# %% [markdown]
# 5. Standarisasi data

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
print(x_train_scaled)
print(x_test_scaled)
# Out:
# [[ 0.0039851  -1.39264024  1.16749455 ... -0.74829331 -0.38118081
#   -0.74246277]
#  [-0.2772331   1.20634263 -0.22074477 ... -0.32596595  0.24599459
#    0.79061601]
#  [-0.27141479  1.20634263  0.47337489 ... -0.08463602 -0.38118081
#    0.62027392]
#  ...
#  [ 0.59551302 -1.39264024 -0.91486443 ... -0.68796083  0.24599459
#   -0.4017786 ]
#  [-0.01540926 -0.27879044 -0.91486443 ...  0.03602894 -1.00835621
#    0.79061601]
#  [-0.24523241 -0.27879044  1.16749455 ...  2.44932815 -1.63553161
#   -0.74246277]]
# [[-0.2772331   0.4637761   1.16749455 ...  0.4583563   0.87316999
#    0.96095809]
#  [-0.26462677  0.09249283  0.47337489 ...  0.88068366 -0.38118081
#    0.62027392]
#  [-0.0929867  -1.02135697 -0.91486443 ... -1.65328051 -0.38118081
#   -2.61622572]
#  ...
#  [-0.26850564  1.20634263  1.16749455 ...  2.38899567  1.5003454
#    1.13130018]
#  [-0.2772331  -0.27879044 -1.60898409 ... -0.32596595 -1.00835621
#   -1.08314694]
# ...

# %%
x = StandardScaler
y = Kerusakan_mesin['fail']

print(x)
print(y)
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 939    1
# 940    1
# 941    1
# 942    1
# 943    1
# Name: fail, Length: 944, dtype: int64

# %% [markdown]
# 6. membuat model training

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# c:\Users\Windows\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# 6. evaluasi model

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

f1 = f1_score(y_test, x_test_prediction, average='binary')

# %%
print('akurasi data training :', training_data_accuracy)
print('akurasi data testting :', test_data_accuracy)
print('f1 score:', f1)
print("\nclassification report:\n", classification_report(y_test, x_test_prediction))
# Out:
# akurasi data training : 0.9045936395759717
# akurasi data testting : 0.91005291005291
# f1 score: 0.89375
#
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       221
#            1       0.88      0.91      0.89       157
#
#     accuracy                           0.91       378
#    macro avg       0.91      0.91      0.91       378
# weighted avg       0.91      0.91      0.91       378

# %% [markdown]
# 7. Membuat model prediksi

# %%
input_data = (0, 0, 6, 1, 5, 6, 36, 6, 24)
input_data_as_numpy_array = np.array(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
std_data = scaler.transform(input_data_reshaped)
prediction = model.predict(std_data)
print(std_data)
print(prediction)

if prediction[0] == 0:
    print("tidak ada kerusakan")
else:
    print("ada kerusakan")
# Out:
# [[-0.2772331  -1.39264024  1.16749455 -1.38778128 -0.3105584   1.4016012
#   -0.68796083  0.87316999  1.30164227]]
# [1]
# ada kerusakan
# c:\Users\Windows\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Windows\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 8. simpan model

# %%
import pickle

# %%
filename = 'model_kerusakan_lr.sav'
pickle.dump(model, open(filename, 'wb'))
